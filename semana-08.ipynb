# %% [markdown]
# # Semana 07

# %% [markdown]
# ## Stream Lit

# %% [markdown]
# ### Olá mundo

# %%
import streamlit as st

st.text("Olá, mundo!")
# Out:
# 2026-07-12 14:39:28.036 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-12 14:39:28.097
# ...
#   command:
#
#     streamlit run /home/joaoantoni/Documents/CATI_trainee/.venv/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-07-12 14:39:28.098 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-12 14:39:28.098 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
